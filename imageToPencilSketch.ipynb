# %% [markdown]
# <a href="https://colab.research.google.com/github/19srishti/1D-arrays/blob/main/imageToPencilSketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow 
from skimage import io
from PIL import Image
import matplotlib as plt

# %%
image=io.imread("/content/drive/MyDrive/image/apple.jpeg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=107x127 at 0x7F0276115040>

# %%
grey_filter=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv2_imshow(grey_filter)
# Out:
# <PIL.Image.Image image mode=L size=107x127 at 0x7F027623AA30>

# %%
invert=cv.bitwise_not(grey_filter)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=107x127 at 0x7F027623A610>

# %%
blur=cv.GaussianBlur(invert,(21,21), 0)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=107x127 at 0x7F02761014C0>

# %%
invertedblur=cv.bitwise_not(blur)
cv2_imshow(invertedblur)
# Out:
# <PIL.Image.Image image mode=L size=107x127 at 0x7F02B4FECA00>

# %%
sketch_filter=cv.divide(grey_filter,invertedblur, scale=255.0)
cv2_imshow(sketch_filter)
# Out:
# <PIL.Image.Image image mode=L size=107x127 at 0x7F02B4FEC040>
